# %%
import pandas
import os
import glob
import csv

f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/clim_set2_note1_3.csv', "rt",encoding = 'iso-8859-1') 

reader = csv.reader(f)

filelist = list(reader)

print(filelist[0], filelist[0], len(filelist))
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
# ['RN', 'NOTE_ID', 'PAT_MRN_ID', 'PAT_ID', 'CPT_DATE', 'CPT_CODE', 'PAT_ENC_CSN_ID', 'NOTE_SERVICE_DT_TM', 'DAYS_CPT_NOTE', 'NOTE_DATE', 'NOTE_TYPE', 'LINE', 'NOTE_TEXT'] ['RN', 'NOTE_ID', 'PAT_MRN_ID', 'PAT_ID', 'CPT_DATE', 'CPT_CODE', 'PAT_ENC_CSN_ID', 'NOTE_SERVICE_DT_TM', 'DAYS_CPT_NOTE', 'NOTE_DATE', 'NOTE_TYPE', 'LINE', 'NOTE_TEXT'] 7000001

# %%
for i in range(100):
    print(filelist[i])
# Out:
# ['RN', 'NOTE_ID', 'PAT_MRN_ID', 'PAT_ID', 'CPT_DATE', 'CPT_CODE', 'PAT_ENC_CSN_ID', 'NOTE_SERVICE_DT_TM', 'DAYS_CPT_NOTE', 'NOTE_DATE', 'NOTE_TYPE', 'LINE', 'NOTE_TEXT']
# ...

# %%
#import pandas
import os
import glob
import csv

#f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/CLim_set2visual_field_Table2.csv', "rt",encoding = 'iso-8859-1') 

f = open('/Users/carsonlam/Downloads/CLim_set2visual_field_Table2.csv', "rt",encoding = 'iso-8859-1') 

visual_field_Table2file = csv.reader(f)

visual_field_Table2filelist = list(visual_field_Table2file)
print(len(visual_field_Table2filelist))
# Out:
# 1626062

# %%
for i in range(3903):
    print(visual_field_Table2filelist[i])
# Out:
# ['PAT_MRN_ID', 'PAT_ENC_CSN_ID', 'CONTACT_DATE', 'EXAM_CODE', 'EXAM_VALUE']
# ['10525418', '131000135366', '30-JUN-09', 'VA - Right Distance CC', '20/50']
# ['16094930', '30564815', '25-JUN-09', 'VA - Method', 'Snellen - Linear']
# ['17585282', '30526288', '24-JUN-09', 'intraocular pressure - left', '18']
# ['15780265', '31181927', '29-JUN-09', 'VA - Right Distance SC +-', '+2']
# ['19081785', '131000321257', '22-JUL-09', 'Tonometry - Time', '3:40 PM']
# ['01248392', '31180836', '20-JUL-09', 'VA - Left Distance PH CC', '20/40-2']
# ['16987950', '131000139627', '06-JUL-09', 'VA - Right Distance CC', '20/30']
# ['18461822', '31153147', '05-AUG-09', 'intraocular pressure - left', '13']
# ['19483676', '131004666275', '22-SEP-09', 'intraocular pressure - left', '15']
# ['13153473', '30915158', '01-JUL-09', 'VA - Left Distance CC +-', '-2']
# ['17018458', '131000014697', '24-AUG-09', 'intraocular pressure - right', '14']
# ...

# %%
with open('/Users/carsonlam/Downloads/Clim_set2_vis_T2.tsv', 'rb') as tsvfile:
    total = 0
    count = 0

    for line in tsvfile:
        #total += line.count(';') + 1
        count += 1

    average = total / float(count)
    
#print(total)
print(count)
# Out:
# 29

# %%
#import pandas
import os
import glob
import csv

#f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/CLim_set2visual_field_Table2.csv', "rt",encoding = 'iso-8859-1') 

f = open('/Volumes/Seagate Backup Plus Drive/MacroEyes/2nd_extraction/CLim_set2_demographic_Table3.csv', "rt",encoding = 'iso-8859-1') 

visual_field_Table2file = csv.reader(f)

visual_field_Table2filelist = list(visual_field_Table2file)
print(len(visual_field_Table2filelist))
# Out:
# 18694

# %%
import os
import glob
import csv

#f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/CLim_set2visual_field_Table2.csv', "rt",encoding = 'iso-8859-1') 

f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/clim_set2_note1_3.csv', "rt",encoding = 'iso-8859-1') 

visual_field_Table2file = csv.reader(f)

visual_field_Table2filelist = list(visual_field_Table2file)
print(len(visual_field_Table2filelist))

# %%
import os
import glob
import csv


f = open('/Volumes/Seagate Backup Plus Drive/2nd_extraction/meds.csv', "rt",encoding = 'iso-8859-1') 

meds = csv.reader(f)

visual_field_Table2filelist = list(visual_field_Table2file)
print(len(visual_field_Table2filelist))
